# %% [markdown]
# *** Every Saturday, at the same time, an individual stands by the side of a road and tallies the number of cars going by within a 120-minute window. Based on previous knowledge, she believes that the mean number of cars going by during this time is exactly 107. Let X represent the appropriate Poisson random variable of the number of cars passing her position in each Saturday session. ***
#
# *** a. What is the probability that more than 100 cars pass her on any given Saturday?***

# %%
#P(X>=100) = 1 - P(X<100) 
1 - ppois(q=100, 107)
# Out:
# [1] 0.7319128

# %% [markdown]
# *** b. Determine the probability that no cars pass.***

# %%
#P(X=0)
dpois(x=0,lambda=107)
# Out:
# [1] 3.39227e-47

# %% [markdown]
# *** c. Plot the relevant Poisson mass function over the values in 60 ≤ x ≤ 150. ***

# %%
#P(X=x)
barplot(dpois(60:150, lambda=107), space = 0, names.arg = 60:150, ylab = "P(X=x)", xlab = "x")
# Out:
# plot without title

# %% [markdown]
# *** d. Simulate 260 results from this distribution (about five years of weekly Saturday monitoring sessions). Plot the simulated results using hist; use xlim to set the horizontal limits from 60 to 150. Compare your histogram to the shape of your mass function from (c). ***

# %%
value <- rpois(n=260,lambda = 107)
hist(value, breaks = seq(60,150,1), col = "gray", xlim = c(60,160), ylim = c(0,20), xlab = "x", ylab = "Count")
# Out:
# Plot with title “Histogram of value”
